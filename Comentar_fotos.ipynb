# %%
import os
from selenium import webdriver
import time 
from selenium.webdriver.common.keys import Keys

# %%
f = open('credenciales.txt', 'r')
us = f.readline().strip()
pas = f.readline().strip()

# %%
ruta = os.getcwd()
driver_path = '{}\geckodriver.exe'.format(ruta)
driver = webdriver.Firefox()
driver.get('https://www.instagram.com/')

# %%
#find username
username = driver.find_element_by_name('username')
username.click()
username.send_keys(us)

#find password
password = driver.find_element_by_name('password')
password.click()
password.send_keys(pas)
# Out:
# C:\Users\Ana\AppData\Local\Temp\ipykernel_6044\3686328649.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   username = driver.find_element_by_name('username')
# C:\Users\Ana\AppData\Local\Temp\ipykernel_6044\3686328649.py:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   password = driver.find_element_by_name('password')

# %%
login = driver.find_element_by_xpath('//div[text()="Log In"]')
login.click()
# Out:
# C:\Users\Ana\AppData\Local\Temp\ipykernel_6044\3443195610.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   login = driver.find_element_by_xpath('//div[text()="Log In"]')

# %%
try:
    info_se = driver.find_element_by_xpath('//button[text()="Not Now"]')
    info_se.click()
    time.sleep(2)
except:
    pass
# Out:
# C:\Users\Ana\AppData\Local\Temp\ipykernel_6044\2982572242.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   info_se = driver.find_element_by_xpath('//button[text()="Not Now"]')

# %%
try:
    activ_not = driver.find_element_by_xpath('//button[text()="Not Now"]')
    activ_not.click()
    time.sleep(2)
except:
    pass
# Out:
# C:\Users\Ana\AppData\Local\Temp\ipykernel_6044\832281762.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   activ_not = driver.find_element_by_xpath('//button[text()="Not Now"]')

# %%
search = driver.find_element_by_xpath('//div[@class=" QY4Ed P0xOK"]/input')
search.send_keys('animalessalvajes.365')
# Out:
# C:\Users\Ana\AppData\Local\Temp\ipykernel_6044\2599725533.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search = driver.find_element_by_xpath('//div[@class=" QY4Ed P0xOK"]/input')

# %%
account = driver.find_element_by_xpath('//div[@class="fuqBx "]/div[1]/a/div')
account.click()
# Out:
# C:\Users\Ana\AppData\Local\Temp\ipykernel_6044\702819966.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   account = driver.find_element_by_xpath('//div[@class="fuqBx "]/div[1]/a/div')

# %%
fotos = driver.find_elements_by_xpath('//div[@class="v1Nh3 kIKUG  _bz0w"]/a')
# Out:
# C:\Users\Ana\AppData\Local\Temp\ipykernel_6044\2213468772.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   fotos = driver.find_elements_by_xpath('//div[@class="v1Nh3 kIKUG  _bz0w"]/a')

# %%
publi = driver.find_element_by_xpath('//ul[@class="k9GMp "]//li[1]//span').text
# Out:
# C:\Users\Ana\AppData\Local\Temp\ipykernel_6044\3161721838.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   publi = driver.find_element_by_xpath('//ul[@class="k9GMp "]//li[1]//span').text

# %%
fotos = []

# %%
while True:
    driver.execute_script("""window.scrollTo(0,document.body.scrollHeight)""")
    time.sleep(2)
    f = driver.find_elements_by_xpath('//div[@class="v1Nh3 kIKUG _bz0w"]/a')
    f = [i.get_attribute('href') for i in f ]
    for i in f :
        if i not in fotos:
            fotos.append(i)
    print(len(fotos))        
    if len(fotos) == int(publi):
        break
# Out:
# C:\Users\Ana\AppData\Local\Temp\ipykernel_6044\2747572828.py:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   f = driver.find_elements_by_xpath('//div[@class="v1Nh3 kIKUG _bz0w"]/a')
# 36
# 48
# 60
# 72
# 84
# 96
# 108
# 120
# 132
# 144
# 156
# 168
# 180
# 192
# 204
# 216
# 228
# 240
# 252
# 264
# 276
# 288
# 300
# 312
# 324
# 336
# 348
# 360
# 372
# 384
# 396
# 408
# 420
# 432
# 444
# 456
# 468
# 480
# 492
# 504
# 516
# 528
# 540
# 552
# 564
# 576
# 588
# 600
# 612
# 624
# 636
# 648
# 660
# 661

# %%
fotos
# Out:
# ['https://www.instagram.com/p/CRPJg1AhC9V/',
#  'https://www.instagram.com/p/CQ8lQGahMgE/',
#  'https://www.instagram.com/p/CQv7RfKBmv-/',
#  'https://www.instagram.com/p/CQi668MBTif/',
#  'https://www.instagram.com/p/CQWJUzzhDC2/',
#  'https://www.instagram.com/p/CQSBUhVBaWo/',
#  'https://www.instagram.com/p/CQLxoldhLIh/',
#  'https://www.instagram.com/p/CQHBfeUhZUB/',
#  'https://www.instagram.com/p/CQCAI4TBm1J/',
#  'https://www.instagram.com/p/CP5mdvrBAM5/',
#  'https://www.instagram.com/p/CP1lsFFhpLa/',
#  'https://www.instagram.com/p/CPxx9thh2MU/',
#  'https://www.instagram.com/p/CPlgePiBgCJ/',
#  'https://www.instagram.com/p/CPgDHUQhEFx/',
#  'https://www.instagram.com/p/CPY_q0eB8si/',
#  'https://www.instagram.com/p/CPUIWxRB26Y/',
#  'https://www.instagram.com/p/CPOIJ_lBaeY/',
#  'https://www.instagram.com/p/CPHGcH8Bskd/',
#  'https://www.instagram.com/p/CPEREbsh1pv/',
#  'https://www.instagram.com/p/CO-xiFABT8L/',
#  'https://www.instagram.com/p/CO5WtcdhqIA/',
# ...

# %%
for i in fotos:
    driver.get(i)
    comentar = driver.find_element_by_xpath('//section[@class="ltpMr  Slqrh "]//span[@class="_15y0l"]//button').click()
    escribir = driver.find_element_by_xpath('//form[@class="X7cDz"]//textarea')
    escribir.send_keys('Awwww!')
    enviar = driver.find_element_by_xpath('//form[@class="X7cDz"]//button[@class="sqdOP yWX7d    y3zKF     "]').click()
    time.sleep(1.5)
    try:
        no_publica = driver.find_element_by_xpath('//div[@class="_1XyCr  "]//div//div//h3[contains(text(), "Try Again Later")]').text 
        boton = driver.find_element_by_xpath('//div[@class="mt3GC"]//button[@class="aOOlW   HoLwm "]').click()
    except:
        no_publica = ""
        
    if len(no_publica) > 0:
        while True:
            enviar = driver.find_element_by_xpath('//form[@class="X7cDz"]//button[@class="sqdOP yWX7d    y3zKF     "]').click()
            time.sleep(10)
            try:
                no_publica = driver.find_element_by_xpath('//div[@class="_1XyCr  "]//div//div//h3[contains(text(), "Try Again Later")]').text 
                boton = driver.find_element_by_xpath('//div[@class="mt3GC"]//button[@class="aOOlW   HoLwm "]').click()
            except:
                break
            time.sleep(30)
    time.sleep(10)
    #no_publica = driver.find_element_by_xpath('//')
# Out:
# C:\Users\Ana\AppData\Local\Temp\ipykernel_6044\1714012761.py:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   comentar = driver.find_element_by_xpath('//section[@class="ltpMr  Slqrh "]//span[@class="_15y0l"]//button').click()
# C:\Users\Ana\AppData\Local\Temp\ipykernel_6044\1714012761.py:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   escribir = driver.find_element_by_xpath('//form[@class="X7cDz"]//textarea')
# C:\Users\Ana\AppData\Local\Temp\ipykernel_6044\1714012761.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   enviar = driver.find_element_by_xpath('//form[@class="X7cDz"]//button[@class="sqdOP yWX7d    y3zKF     "]').click()
# C:\Users\Ana\AppData\Local\Temp\ipykernel_6044\1714012761.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...
